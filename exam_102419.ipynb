# %% [markdown]
# 1. Linear regression is a supervised machine learning alogorithm
#
# Answer: True
#
# 2. Which method do we use to find the best fit for data in linear regression
#
# a. least square error
# b. maximum likelihood
# c. logarythmic loss
# d. both a and b
#
# Answer a.
#
# 3. Which of the following is true for residuals?
#
# a. lower is better
# b. higher is better
# c a or b depending of situation
# d. none of these
#
# Answer a.
#
# 4. What will happen when you fit degree 2 polynomial in linear regression
#
# Answer: Should work but isn't really a linear regrssion anymore
#
# 5. Is it possible to design a linear regression algoritm using a neural network
#
# Answer: True
#
# 6. Which of the following evaluation metrics can be used to evaluate a model while modeling a continuous output
#
# a AUC ROC
# b. accuracy
# c. log loss
# d. mean square error
#
# 7. Which of the following statements is true about outliers in linear regression?
#
# a linear regression is sensitiv to outliers
# b it is not sensitiv to outliers
# c can't say
# d none of this
#
# Answer a
#
# 8. Suppose you plotted a scatter plot between the residuals and predicted values in linear regression and you found there is a relationship between them what does that mean?
#
# a since there is a relationshiop model is not good
# b since there is a relationship model is good
# c can't say
# d. none of those
#
# Answer a
#
#
# 9. Suppose we have N independent variables( x1, x2, x3, xn) and dependent variable is y
# imagine we are applying linear regression by fitting the best fit line using least square error on this data. We found that correlation. coefficient for one of this variable say x1 with y is .95. Which of the following is true for x1
#
# a relation between x and y is weak
# b relation between x and y is strong
# c relation between x and y is neutral
# d cannot judge the relationship
#
# Answer b because a correlation coefficient is measured between - 1 and + 1 whereas a coefficent of + .95 equals almost perfect positiv correlation
#
# 10. Suppose you have a dataset D1 and you design a linear regression model of degree 3 polynomial and we found that the training and testing error is zero or in other terms it perfectly fits the data. What will happen when we fit a degree 4 polynomial in linear regression
#
# a high chances that degree 4 polynomial will overfit the data
# b high chances that degree 4 polynomial will underfit the data
# c can't say
# d none of these
#
# Answer: ?
